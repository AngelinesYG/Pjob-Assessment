# %%
print('hello')
# Out:
# hello

# %%
from bs4 import BeautifulSoup
import requests
import json

base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'

payload = {
"value": 'Form W-2',
"criteria": 'formNumber',
"submitSearch": 'Find',
}
r = requests.get(base_url, params=payload)
c = r.content
soup = BeautifulSoup(c, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
#  <head>
#   <script src="/app/picklist/scripts/common.js;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" type="text/javascript">
#   </script>
#   <title>
#    Prior Year Products
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <link href="/static_assets/img/icons/favicon.ico" rel="shortcut icon"/>
#   <link href="/w3c/p3p.xml" rel="P3Pv1"/>
#   <link href="/static_assets/css/layout.css" rel="stylesheet"/>
#   <link href="/static_assets/css/main.css" rel="stylesheet"/>
#   <script src="/static_assets/js/reporting/iep-reporting.js" type="text/javascript">
#   </script>
#  </head>
#  <body onload="setDivHeight()">
#   <div id="main">
#    <!--googleoff: all-->
#    <div class="header">
#     <a class="logo" href="http://www.irs.gov/">
#      <img alt="Internal Revenue Service United States Department of the Treasury" src="/static_assets/img/logo.png" title="Internal Revenue Service United States Department of the Treasury"/>
#     </a>
#    </div>
#    <div class="hr">
#     <hr/>
#    </div>
#    <!--googleon: all-->
#    <div class="body" id="body">
#     <div class="leftnav" id="leftNavDiv">
#      <!--googleoff: all-->
#      <!-- Left navigation links -->
#      <!--googleon: all-->
#     </div>
#     <div class="content">
#      <div id="picklistContentPane">
#       <div class="pageLabel">
#        Prior Year Products
#       </div>
#       <div class="instructionsBaseSGML">
#        <table>
#         <tr>
#          <td class="bold">
#           Instructions:
#          </td>
#          <td class="bold">
#           Tips:
#          </td>
#          <td class="bold">
#           More Information:
#          </td>
#         </tr>
#         <tr>
#          <td valign="top">
#           <ol>
#            <li>
#             Enter a term in the Find Box.
#            </li>
#            <li>
#             Select a category (column heading) in the drop down.
#            </li>
#            <li>
#             Click Find.
#            </li>
#           </ol>
#          </td>
#          <td valign="top">
#           <ul>
#            <li>
#             Click on the product number in each row to view/download.
#            </li>
#            <li>
#             Click on column heading to sort the list.
#            </li>
#            <li>
#             You may be able to
#             <a href="/app/scripts/mapper.jsp?page=pickList_enter_information_link">
#              enter information
#             </a>
#             on forms before saving or printing.
#            </li>
#           </ul>
#          </td>
#          <td valign="top">
#           <ul>
#            <li>
#             <a href="/app/scripts/mapper.jsp?page=pickList_download_printing_link">
#              Downloading and printing
#             </a>
#            </li>
#            <li>
#             <a href="/app/scripts/mapper.jsp?page=pickList_file_formats_link">
#              File formats
#             </a>
#            </li>
#            <li>
#             <a href="/app/scripts/mapper.jsp?page=pickList_view_save_doc_link">
#              View and/or save documents
#             </a>
#            </li>
#           </ul>
#          </td>
#         </tr>
#        </table>
#       </div>
#       <div class="picklistFormPubNotice">
#        <form action="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" method="GET">
#        </form>
#        <table>
#         <tr>
#          <td>
#           <b>
#            <label for="searchFor">
#             Find
#            </label>
#           </b>
#          </td>
#          <td>
#           <input id="searchFor" maxlength="30" name="value" size="20" type="text" value="Form W-2"/>
#          </td>
#          <td>
#           <b>
#            <label for="criteria">
#             in
#            </label>
#           </b>
#          </td>
#          <td>
#           <select name="criteria">
#            <option value="formNumber">
#             Product Number
#            </option>
#            <option value="title">
#             Title
#            </option>
#            <option value="currentYearRevDateString">
#             Revision Date
#            </option>
#           </select>
#          </td>
#          <td>
#           <input name="submitSearch" type="submit" value="Find"/>
#          </td>
#          <td>
#           <a href="/app/scripts/mapper.jsp?page=pickList_search_help">
#            Find Help
#           </a>
#          </td>
#         </tr>
#        </table>
#       </div>
#       <div class="searchFields">
#        <hr/>
#        <table class="searchFieldsTable">
#         <tr>
#          <th class="ShowByColumn" scope="col" style="width:33%">
#           Results:
#  	  1 - 25 of 227 files
#          </th>
#          <th class="NumResultsDisplayed" scope="col" style="width:33%">
#           Show per page:
#           <b>
#            25
#           </b>
#           <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?resultsPerPage=50&amp;sortColumn=sortOrder&amp;indexOfFirstRow=0&amp;criteria=formNumber&amp;value=Form+W-2&amp;isDescending=false">
#            50
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?resultsPerPage=100&amp;sortColumn=sortOrder&amp;indexOfFirstRow=0&amp;criteria=formNumber&amp;value=Form+W-2&amp;isDescending=false">
#            100
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?resultsPerPage=200&amp;sortColumn=sortOrder&amp;indexOfFirstRow=0&amp;criteria=formNumber&amp;value=Form+W-2&amp;isDescending=false">
#            200
#           </a>
#          </th>
#          <th class="NumPageViewed" scope="col" style="width:33%">
#           « Previous |
#           <b>
#            1
#           </b>
#           <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=25&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            2
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=50&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            3
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=75&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            4
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=100&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            5
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=125&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            6
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=150&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            7
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=175&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            8
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=200&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            9
#           </a>
#           <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=225&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            10
#           </a>
#           |
#           <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?indexOfFirstRow=25&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#            Next »
#           </a>
#          </th>
#         </tr>
#        </table>
#       </div>
#       <div class="picklistTable">
#        <table class="picklist-dataTable">
#         <tr>
#          <th class="FormNumber" scope="col">
#           <b>
#            <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?sortColumn=sortOrder&amp;indexOfFirstRow=0&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=true
# 		">
#             <span class="picklistColumnHeader">
#              Product Number
#             </span>
#            </a>
#            <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?sortColumn=sortOrder&amp;indexOfFirstRow=0&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=true
# 					">
#             <img alt="Sorted Ascending" src="/app/picklist/images/ascendingArrows.gif;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" title="Sorted Ascending"/>
#            </a>
#            <a href="/app/picklist/help/formsPublicationsFormNumber.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" onclick="returnLink('/app/picklist/help/formsPublicationsFormNumber.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21', 520, 470); return false;" style="A.help:hover; cursor:help; " target="winhelp">
#             <img alt="Help on Publication or Notice Number" src="/app/picklist/images/questionMark.gif;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" title="Help on Publication or Notice Number"/>
#            </a>
#           </b>
#          </th>
#          <th class="Title" scope="col">
#           <b>
#            <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?sortColumn=title&amp;indexOfFirstRow=0&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false
# 		">
#             <span class="picklistColumnHeader">
#              Title
#             </span>
#            </a>
#            <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?sortColumn=title&amp;indexOfFirstRow=0&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false
# 					">
#             <img alt="Not sorted" src="/app/picklist/images/neutralArrows.gif;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" title="Not sorted"/>
#            </a>
#            <a href="/app/picklist/help/formsPublicationsTitle.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" onclick="returnLink('/app/picklist/help/formsPublicationsTitle.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21', 520, 470); return false;" style="A.help:hover; cursor:help; " target="winhelp">
#             <img alt="Help on Title" src="/app/picklist/images/questionMark.gif;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" title="Help on Title"/>
#            </a>
#           </b>
#          </th>
#          <th class="CurrentYear" scope="col">
#           <b>
#            <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?sortColumn=currentYearRevDate&amp;indexOfFirstRow=0&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false
# 		">
#             <span class="picklistColumnHeader">
#              Revision Date
#             </span>
#            </a>
#            <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?sortColumn=currentYearRevDate&amp;indexOfFirstRow=0&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false
# 					">
#             <img alt="Not sorted" src="/app/picklist/images/neutralArrows.gif;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" title="Not sorted"/>
#            </a>
#            <a href="/app/picklist/help/formsPublicationsCurrentYearRevDate.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" onclick="returnLink('/app/picklist/help/formsPublicationsCurrentYearRevDate.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21', 520, 470); return false;" style="A.help:hover; cursor:help; " target="winhelp">
#             <img alt="Help on Revision Date" src="/app/picklist/images/questionMark.gif;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" title="Help on Revision Date"/>
#            </a>
#           </b>
#          </th>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1990.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1990
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1989.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1989
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1988.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1988
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1987.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1987
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1986.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1986
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1985.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1985
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1984.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1984
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1983.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1983
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1982.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1982
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1981.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1981
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1980.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1980
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1979.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1979
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1978.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1978
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1977.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1977
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1976.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1976
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1975.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1975
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1974.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1974
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1973.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1973
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1972.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1972
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2p--1971.pdf">
#            Form W-2 P
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments
#          </td>
#          <td class="EndCellSpacer">
#           1971
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2--2021.pdf">
#            Form W-2
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Wage and Tax Statement (Info Copy Only)
#          </td>
#          <td class="EndCellSpacer">
#           2021
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2--2020.pdf">
#            Form W-2
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Wage and Tax Statement (Info Copy Only)
#          </td>
#          <td class="EndCellSpacer">
#           2020
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2--2019.pdf">
#            Form W-2
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Wage and Tax Statement (Info Copy Only)
#          </td>
#          <td class="EndCellSpacer">
#           2019
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2--2018.pdf">
#            Form W-2
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Wage and Tax Statement (Info Copy Only)
#          </td>
#          <td class="EndCellSpacer">
#           2018
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="LeftCellSpacer">
#           <a href="https://www.irs.gov/pub/irs-prior/fw2--2017.pdf">
#            Form W-2
#           </a>
#          </td>
#          <td class="MiddleCellSpacer">
#           Wage and Tax Statement (Info Copy Only)
#          </td>
#          <td class="EndCellSpacer">
#           2017
#          </td>
#         </tr>
#        </table>
#        <hr/>
#       </div>
#       <div class="paginationBottom">
#        « Previous |
#        <b>
#         1
#        </b>
#        <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=25&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         2
#        </a>
#        <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=50&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         3
#        </a>
#        <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=75&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         4
#        </a>
#        <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=100&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         5
#        </a>
#        <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=125&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         6
#        </a>
#        <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=150&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         7
#        </a>
#        <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=175&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         8
#        </a>
#        <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=200&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         9
#        </a>
#        <a href="/app/picklist/list/priorFormPublication.html?indexOfFirstRow=225&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         10
#        </a>
#        |
#        <a href="/app/picklist/list/priorFormPublication.html;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21?indexOfFirstRow=25&amp;sortColumn=sortOrder&amp;value=Form+W-2&amp;criteria=formNumber&amp;resultsPerPage=25&amp;isDescending=false">
#         Next »
#        </a>
#       </div>
#       <a href="http://www.adobe.com">
#        <img alt="Official Adobe Website" src="/app/picklist/images/get_adobe_reader.gif;jsessionid=e3ZAgdmrSKRMJArTOwg44AmJ.21" title="Official Adobe Website"/>
#       </a>
#       <br/>
#       <a href="http://www.adobe.com">
#        Get Adobe ® Reader
#       </a>
#      </div>
#     </div>
#     <!-- content -->
#    </div>
#    <!-- body -->
#    <!--googleoff: all-->
#    <div class="push">
#    </div>
#   </div>
#   <!-- main -->
#   <div class="footer" id="footerDiv">
#    <div class="legal">
#     <p>
#     </p>
#    </div>
#   </div>
#   <!-- Start GA AutoTracker Code -->
#   <script src="/static_assets/js/libs/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="/static_assets/js/reporting/autotracker.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    addLinkerEvents()
#   </script>
#   <!--End AutoTracker Code -->
#  </body>
# </html>

# %%
from bs4 import BeautifulSoup
import requests
import json

base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'

payload = {
"value": 'Form W-2',
"criteria": 'formNumber',
"submitSearch": 'Find',
}
r = requests.get(base_url, params=payload)
c = r.content
soup = BeautifulSoup(c, 'lxml')
# print(soup.prettify())

table = soup.find("table", class_= "picklist-dataTable")
table_data = table.find_all('tr')

headings = []
for td in table_data[0].find_all("th"):
    headings.append(td.b.text.replace('\n', ' ').strip())

print(headings)
# Out:
# ['Product Number', 'Title', 'Revision Date']

# %%
from bs4 import BeautifulSoup
import requests
import json

base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'

payload = {
"value": 'Form W-2',
"criteria": 'formNumber',
"submitSearch": 'Find',
}
r = requests.get(base_url, params=payload)
c = r.content
soup = BeautifulSoup(c, 'lxml')

table = soup.find("table", class_= "picklist-dataTable")
table_data = table.find_all('tr')

headings = []
for td in table_data[0].find_all("th"):
    headings.append(td.b.text.replace('\n', ' ').strip())

t_row_data = []
for tr in table.find_all("tr"):
    t_row = {}
for td, th in zip(tr.find_all("td"), headings):
    t_row[th] = td.text.replace('\n', '').strip()
    t_row_data.append(t_row)

print(t_row_data)
# Out:
# [{'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2017'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2017'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2017'}]

# %%
from bs4 import BeautifulSoup
import requests
import json

base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
# data = []
i = 0
t_row_data = []
while True:
    payload = {
"value": 'Form W-2',
"criteria": 'formNumber',
'sortColumn': 'sortOrder',
'indexOfFirstRow': i,
'isDescending': 'false',
'resultsPerPage': 25,
}


r = requests.get(base_url, params=payload)
c = r.content
soup = BeautifulSoup(c, 'lxml')
# print(soup.prettify())
table = soup.find("table", class_= "picklist-dataTable")
table_data = table.find_all('tr')

headings = []
for td in table_data[0].find_all("th"):
    headings.append(td.b.text.replace('\n', ' ').strip())

# t_row_data = []
for tr in table.find_all("tr"):
    t_row = {}
for td, th in zip(tr.find_all("td"), headings):
    t_row[th] = td.text.replace('\n', '').strip()
    t_row_data.append(t_row)
if t_row == {}:
    break
    i += 25

print(t_row_data)

# %%
from bs4 import BeautifulSoup
import requests
import json

base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'

i = 0
t_row_data = []
while True:
    payload = {
"value": 'Form W-2',
"criteria": 'formNumber',
'sortColumn': 'sortOrder',
'indexOfFirstRow': i,
'isDescending': 'false',
'resultsPerPage': 25,
}


r = requests.get(base_url, params=payload)
c = r.content
soup = BeautifulSoup(c, 'lxml')
table = soup.find("table", class_= "picklist-dataTable")
table_data = table.find_all('tr')

headings = []
for td in table_data[0].find_all("th"):
    headings.append(td.b.text.replace('\n', ' ').strip())


for tr in table.find_all("tr"):
    t_row = {}
for td, th in zip(tr.find_all("td"), headings):
    t_row[th] = td.text.replace('\n', '').strip()
    t_row_data.append(t_row)
if t_row == {}:
break
i += 25

print(t_row_data)

# %%
from bs4 import BeautifulSoup
import requests
import json
 
base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
 
i = 0
t_row_data = []
while True:
    payload = { 
        "value": 'Form W-2',
        "criteria": 'formNumber',
        'sortColumn': 'sortOrder',
        'indexOfFirstRow': i,
        'isDescending': 'false',
        'resultsPerPage': 25, 
    }
 
 
    r = requests.get(base_url, params=payload)
    c = r.content
    soup = BeautifulSoup(c, 'lxml')
    # print(soup.prettify())
    table = soup.find("table", class_= "picklist-dataTable")
    table_data = table.find_all('tr')
 
    headings = []
    for td in table_data[0].find_all("th"):
        headings.append(td.b.text.replace('\n', ' ').strip())
 
    # t_row_data = []
    for tr in table.find_all("tr"):
        t_row = {}
        for td, th in zip(tr.find_all("td"), headings): 
            t_row[th] = td.text.replace('\n', '').strip()
        t_row_data.append(t_row)
    if t_row == {}:
       break
    i += 25
 
print(t_row_data)

# %%
from bs4 import BeautifulSoup
import requests
import json

base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'

i = 0
t_row_data = []
while True:
    payload = { 
        "value": 'Form W-2',
        "criteria": 'formNumber',
        'sortColumn': 'sortOrder',
        'indexOfFirstRow': i,
        'isDescending': 'false',
        'resultsPerPage': 25, 
    }


    r = requests.get(base_url, params=payload)
    c = r.content
    soup = BeautifulSoup(c, 'lxml')
    # print(soup.prettify())
    table = soup.find("table", class_= "picklist-dataTable")
    table_data = table.find_all('tr')

    headings = []
    for td in table_data[0].find_all("th"):
        headings.append(td.b.text.replace('\n', ' ').strip())

    # t_row_data = []
    for tr in table.find_all("tr"):
        t_row = {}
        for td, th in zip(tr.find_all("td"), headings): 
            t_row[th] = td.text.replace('\n', '').strip()
        t_row_data.append(t_row)
    if t_row == {}:
       break
    i += 25

print(t_row_data)

# %%
from bs4 import BeautifulSoup
import requests
import json
 
base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
 
i = 0
t_row_data = []
while True:
    payload = { 
        "value": 'Form W-2',
        "criteria": 'formNumber',
        'sortColumn': 'sortOrder',
        'indexOfFirstRow': i,
        'isDescending': 'false',
        'resultsPerPage': 25, 
    }
 
 
    r = requests.get(base_url, params=payload)
    c = r.content
    soup = BeautifulSoup(c, 'lxml')
    # print(soup.prettify())
    table = soup.find("table", class_= "picklist-dataTable")
    table_data = table.find_all('tr')
 
    headings = []
    for td in table_data[0].find_all("th"):
        headings.append(td.b.text.replace('\n', ' ').strip())
 
    # t_row_data = []
    for tr in table.find_all("tr"):
        t_row = {}
        for td, th in zip(tr.find_all("td"), headings): 
            t_row[th] = td.text.replace('\n', '').strip()
        t_row_data.append(t_row)
    if t_row == {}:
        break
    i += 25
 
print(t_row_data)

# %%
from bs4 import BeautifulSoup
import requests
import json
 
base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
 
i = 0
t_row_data = []
while True:
    payload = { 
        "value": 'Form W-2',
        "criteria": 'formNumber',
        'sortColumn': 'sortOrder',
        'indexOfFirstRow': i,
        'isDescending': 'false',
        'resultsPerPage': 25, 
    }
 
 
    r = requests.get(base_url, params=payload)
    c = r.content
    soup = BeautifulSoup(c, 'lxml')
    # print(soup.prettify())
    table = soup.find("table", class_= "picklist-dataTable")
    table_data = table.find_all('tr')
 
    headings = []
    for td in table_data[0].find_all("th"):
        headings.append(td.b.text.replace('\n', ' ').strip())
 
    # t_row_data = []
    for tr in table.find_all("tr"):
        t_row = {}
        for td, th in zip(tr.find_all("td"), headings): 
            t_row[th] = td.text.replace('\n', '').strip()
        t_row_data.append(t_row)
    if t_row == {}:
        break
    i += 25
 
print(t_row_data)
# Out:
# [{}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1990'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1989'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1988'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1987'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1986'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1985'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1984'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1983'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1982'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1981'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1980'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1979'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1978'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1977'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1976'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1975'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1974'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1973'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1972'}, {'Product Number': 'Form W-2 P', 'Title': 'Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments', 'Revision Date': '1971'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2021'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2020'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2019'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2018'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2017'}, {}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2016'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2015'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2014'}, {'Product Number': 'Form W-2', 'Title': 'Wage and Tax Statement (Info Copy Only)', 'Revision Date': '2013'}, {'Product Number': 'Form W-2', ...

# %%
from bs4 import BeautifulSoup
import requests
import json
 
base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
 
i = 0
t_row_data = []
while True:
    payload = { 
        "value": 'Form W-2',
        "criteria": 'formNumber',
        'sortColumn': 'sortOrder',
        'indexOfFirstRow': i,
        'isDescending': 'false',
        'resultsPerPage': 25, 
    }
 
 
    r = requests.get(base_url, params=payload)
    c = r.content
    soup = BeautifulSoup(c, 'lxml')
    # print(soup.prettify())
    table = soup.find("table", class_= "picklist-dataTable")
    table_data = table.find_all('tr')
 
    headings = []
    for td in table_data[0].find_all("th"):
        headings.append(td.b.text.replace('\n', ' ').strip())
 
    # t_row_data = []
    for tr in table.find_all("tr"):
        t_row = {}
        for td, th in zip(tr.find_all("td"), headings): 
            t_row[th] = td.text.replace('\n', '').strip()
        t_row_data.append(t_row)
    if t_row == {}:
        break
    i += 25
 
years = []
result = {}
 
for row in t_row_data[1:]:
    if row != {} and row['Product Number'] == 'Form W-2':
        years.append(row['Revision Date'])
 
for row in t_row_data[1:]:
    if row != {} and row['Product Number'] == 'Form W-2':
        years.append(row['Revision Date'])
        result['form_number'] = row['Product Number']
        result['form_title'] = row['Title']
        break
 
result['min_year'] = min(years)
result['max_year'] = max(years)
 
print(json.dumps(result, indent=4))
# Out:
# {
#     "form_number": "Form W-2",
#     "form_title": "Wage and Tax Statement (Info Copy Only)",
#     "min_year": "1954",
#     "max_year": "2021"
# }

# %%
from bs4 import BeautifulSoup
import requests
import json
 
 
def scraper(form_name):
    base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
 
    i = 0
    t_row_data = []
    while True:
        payload = { 
            "value": form_name,
            "criteria": 'formNumber',
            'sortColumn': 'sortOrder',
            'indexOfFirstRow': i,
            'isDescending': 'false',
            'resultsPerPage': 25, 
        }
 
 
        r = requests.get(base_url, params=payload)
        c = r.content
        soup = BeautifulSoup(c, 'lxml')
        # print(soup.prettify())
        table = soup.find("table", class_= "picklist-dataTable")
        table_data = table.find_all('tr')
 
        headings = []
        for td in table_data[0].find_all("th"):
            headings.append(td.b.text.replace('\n', ' ').strip())
 
        # t_row_data = []
        for tr in table.find_all("tr"):
            t_row = {}
            for td, th in zip(tr.find_all("td"), headings): 
                t_row[th] = td.text.replace('\n', '').strip()
            t_row_data.append(t_row)
        if t_row == {}:
            break
        i += 25
 
    years = []
    result = {}
 
    for row in t_row_data[1:]:
      if row != {} and row['Product Number'] == form_name:
        years.append(row['Revision Date'])
 
    for row in t_row_data[1:]:
      if row != {} and row['Product Number'] == form_name:
        years.append(row['Revision Date'])
        result['form_number'] = row['Product Number']
        result['form_title'] = row['Title']
        break
 
    result['min_year'] = min(years)
    result['max_year'] = max(years)
 
    print(json.dumps(result, indent=4))
 
form_name = input("Enter the form you want to search for >>> ").strip()
scraper(form_name)
# Out:
# Enter the form you want to search for >>> w-2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4t/s69_ftcx1w549f737tvnp7g80000gn/T/ipykernel_12133/1676384542.py in <module>
#      61
#      62 form_name = input("Enter the form you want to search for >>> ").strip()
# ---> 63 scraper(form_name)
#
# /var/folders/4t/s69_ftcx1w549f737tvnp7g80000gn/T/ipykernel_12133/1676384542.py in scraper(form_name)
#      55         break
#      56
# ---> 57     result['min_year'] = min(years)
#      58     result['max_year'] = max(years)
#      59
#
# ValueError: min() arg is an empty sequence

# %%
from bs4 import BeautifulSoup
import requests
import json
 
 
def scraper(form_name):
    base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
    i = 0
    t_row_data = []
    while True:
        payload = { 
            "value": form_name,
            "criteria": 'formNumber',
            'sortColumn': 'sortOrder',
            'indexOfFirstRow': i,
            'isDescending': 'false',
            'resultsPerPage': 25, 
        }
 
        r = requests.get(base_url, params=payload)
        c = r.content
        soup = BeautifulSoup(c, 'lxml')
        table = soup.find("table", class_= "picklist-dataTable")
        table_data = table.find_all('tr')
 
        headings = []
        for td in table_data[0].find_all("th"):
            headings.append(td.b.text.replace('\n', ' ').strip())
 
        for tr in table.find_all("tr"):
            t_row = {}
            for td, th in zip(tr.find_all("td"), headings): 
                t_row[th] = td.text.replace('\n', '').strip()
            t_row_data.append(t_row)
        if t_row == {}:
            break
        i += 25
 
    years = []
    result = {}
 
    for row in t_row_data[1:]:
      if row != {} and row['Product Number'] == form_name:
        years.append(row['Revision Date'])
 
    for row in t_row_data[1:]:
      if row != {} and row['Product Number'] == form_name:
        years.append(row['Revision Date'])
        result['form_number'] = row['Product Number']
        result['form_title'] = row['Title']
        break
 
    result['min_year'] = min(years)
    result['max_year'] = max(years)
 
    return result
 
form_names = input("Enter the form you want to search for >>> ").split(",")
final_data = []
for form_name in form_names:
    final_data.append(scraper(form_name.strip()))
 
print(json.dumps(final_data, indent=4))
# Out:
# Enter the form you want to search for >>> form W-2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4t/s69_ftcx1w549f737tvnp7g80000gn/T/ipykernel_12133/3957919961.py in <module>
#      59 final_data = []
#      60 for form_name in form_names:
# ---> 61     final_data.append(scraper(form_name.strip()))
#      62
#      63 print(json.dumps(final_data, indent=4))
#
# /var/folders/4t/s69_ftcx1w549f737tvnp7g80000gn/T/ipykernel_12133/3957919961.py in scraper(form_name)
#      51         break
#      52
# ---> 53     result['min_year'] = min(years)
#      54     result['max_year'] = max(years)
#      55
#
# ValueError: min() arg is an empty sequence

# %%
from bs4 import BeautifulSoup
import requests
import json
 
 
def scraper(form_name):
    base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
    i = 0
    t_row_data = []
    while True:
        payload = { 
            "value": form_name,
            "criteria": 'formNumber',
            'sortColumn': 'sortOrder',
            'indexOfFirstRow': i,
            'isDescending': 'false',
            'resultsPerPage': 25, 
        }
 
        r = requests.get(base_url, params=payload)
        c = r.content
        soup = BeautifulSoup(c, 'lxml')
        table = soup.find("table", class_= "picklist-dataTable")
        table_data = table.find_all('tr')
 
        headings = []
        for td in table_data[0].find_all("th"):
            headings.append(td.b.text.replace('\n', ' ').strip())
 
        for tr in table.find_all("tr"):
            t_row = {}
            for td, th in zip(tr.find_all("td"), headings): 
                t_row[th] = td.text.replace('\n', '').strip()
            t_row_data.append(t_row)
        if t_row == {}:
            break
        i += 25
 
    years = []
    result = {}
 
    for row in t_row_data[1:]:
      if row != {} and row['Product Number'].lower() == form_name.lower():
        years.append(row['Revision Date'])
 
    for row in t_row_data[1:]:
      if row != {} and row['Product Number'].lower() == form_name.lower():
        years.append(row['Revision Date'])
        result['form_number'] = row['Product Number']
        result['form_title'] = row['Title']
        break
 
    result['min_year'] = min(years)
    result['max_year'] = max(years)
 
    return result
 
form_names = input("Enter the form you want to search for >>> ").split(",")
final_data = []
for form_name in form_names:
    final_data.append(scraper(form_name.strip()))
 
print(json.dumps(final_data, indent=4))
# Out:
# Enter the form you want to search for >>> Publ 1
# [
#     {
#         "form_number": "Publ 1",
#         "form_title": "Your Rights As A Taxpayer",
#         "min_year": "1996",
#         "max_year": "2017"
#     }
# ]

# %%
  from bs4 import BeautifulSoup
import requests
import json
 
 
def scraper(form_name):
    base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
    i = 0
    t_row_data = []
    while True:
        payload = { 
            "value": form_name,
            "criteria": 'formNumber',
            'sortColumn': 'sortOrder',
            'indexOfFirstRow': i,
            'isDescending': 'false',
            'resultsPerPage': 25, 
        }
 
        r = requests.get(base_url, params=payload)
        c = r.content
        soup = BeautifulSoup(c, 'lxml')
        table = soup.find("table", class_= "picklist-dataTable")
        table_data = table.find_all('tr')
 
        headings = []
        for td in table_data[0].find_all("th"):
            headings.append(td.b.text.replace('\n', ' ').strip())
 
        for tr in table.find_all("tr"):
            t_row = {}
            for td, th in zip(tr.find_all("td"), headings): 
                t_row[th] = td.text.replace('\n', '').strip()
            t_row_data.append(t_row)
        if t_row == {}:
            break
        i += 25
 
    years = []
    result = {}
 
    for row in t_row_data[1:]:
      if row != {} and row['Product Number'].lower() == form_name.lower():
        years.append(row['Revision Date'])
 
    for row in t_row_data[1:]:
      if row != {} and row['Product Number'].lower() == form_name.lower():
        years.append(row['Revision Date'])
        result['form_number'] = row['Product Number']
        result['form_title'] = row['Title']
        break
 
    result['min_year'] = min(years)
    result['max_year'] = max(years)
 
    return result
 
form_names = input("Enter the form you want to search for >>> ").split(",")
final_data = []
for form_name in form_names:
    final_data.append(scraper(form_name.strip()))
 
print(json.dumps(final_data, indent=4))

# %%
from bs4 import BeautifulSoup
import requests
import json
 
base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
# data = []
i = 0
t_row_data = []
while True:
    payload = { 
        "value": 'Form W-2',
        "criteria": 'formNumber',
        'sortColumn': 'sortOrder',
        'indexOfFirstRow': i,
        'isDescending': 'false',
        'resultsPerPage': 25, 
    }
 
 
    r = requests.get(base_url, params=payload)
    c = r.content
    soup = BeautifulSoup(c, 'lxml')
    table = soup.find("table", class_= "picklist-dataTable")
    table_data = table.find_all('tr')
 
    headings = []
    for td in table_data[0].find_all("th"):
        headings.append(td.b.text.replace('\n', ' ').strip())
 
    for tr in table.find_all("tr"):
        t_row = {}
        for td, th in zip(tr.find_all("td"), headings): 
            # print(tr.td.a)
            t_row[th] = td.text.replace('\n', '').strip()
            t_row['link'] = tr.td.a['href']
        t_row_data.append(t_row)
    if t_row == {}:
       break
    i += 25
 
print(t_row_data)

# %%
from bs4 import BeautifulSoup
import requests
import json
 
base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
# data = []
i = 0
t_row_data = []
while True:
    payload = { 
        "value": 'Form W-2',
        "criteria": 'formNumber',
        'sortColumn': 'sortOrder',
        'indexOfFirstRow': i,
        'isDescending': 'false',
        'resultsPerPage': 25, 
    }
 
 
    r = requests.get(base_url, params=payload)
    c = r.content
    soup = BeautifulSoup(c, 'lxml')
    table = soup.find("table", class_= "picklist-dataTable")
    table_data = table.find_all('tr')
 
    headings = []
    for td in table_data[0].find_all("th"):
        headings.append(td.b.text.replace('\n', ' ').strip())
 
    for tr in table.find_all("tr"):
        t_row = {}
        for td, th in zip(tr.find_all("td"), headings): 
            # print(tr.td.a)
            t_row[th] = td.text.replace('\n', '').strip()
            t_row['link'] = tr.td.a['href']
        t_row_data.append(t_row)
    if t_row == {}:
       break
    i += 25
 
print(json.dumps(t_row_data, indent=4))
# Out:
# [
#     {},
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1990.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1989.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1989"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1988.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1988"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1987.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1987"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1986.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1986"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1985.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1985"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1984.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1984"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1983.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1983"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1982.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1982"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1981.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1981"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1980.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1980"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1979.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1979"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1978.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1978"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1977.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1977"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1976.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1976"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1975.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1975"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1974.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1974"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1973.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1973"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1972.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1972"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1971.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1971"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2021.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2020.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2019.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2018.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2018"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2017.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2017"
#     },
#     {},
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2016.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2015.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2014.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2013.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2012.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2011.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2011"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2010.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2009.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2008.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2008"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2007.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2006.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2005.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2004.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2004"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2003.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2002.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2001.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2000.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1999.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1998.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1997.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1996.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1995.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1994.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1993.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1992.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {},
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1991.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1990.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1989.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1989"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1988.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1988"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1987.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1987"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1986.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1986"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1985.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1985"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1984.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1984"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1983.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1983"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1982.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1982"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1981.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1981"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1980.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1980"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1979.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1979"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1978.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1978"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1977.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1977"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1976.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1976"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1975.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1975"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1974.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1974"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1973.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1973"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1972.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1972"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1971.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1971"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1970.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1970"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1969.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1969"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1966.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1966"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1965.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1965"
#     },
#     {},
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1964.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1964"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1963.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1963"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1962.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1962"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1961.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1961"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1960.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1960"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1959.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1959"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1958.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1958"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1957.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1957"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1956.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1956"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1955.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1955"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1954.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1954"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2021.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2020.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2019.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2018.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2018"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2017.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2017"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2016.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2015.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2014.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2013.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2012.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2011.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2011"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2010.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2009.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2008.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2008"
#     },
#     {},
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2007.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2006.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2005.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2004.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2004"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2003.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2002.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2001.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2000.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1999.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1998.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1997.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1996.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1995.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1994.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1993.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1992.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1991.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1990.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2014.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2009.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2006.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2002.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2001.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1999.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1997.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {},
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1994.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1993.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1992.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1991.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1990.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1987.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1987"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1985.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1985"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2021.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2020.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2019.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2018.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2018"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2017.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2017"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2016.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2015.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2014.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2013.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2012.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2011.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2011"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2010.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2009.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2008.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2008"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2007.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2006.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2005.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2004.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2004"
#     },
#     {},
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2003.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2002.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2001.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2000.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1999.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1998.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1997.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1996.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1995.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1994.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1993.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1992.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1991.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1990.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2021.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2020.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2019.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2018.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2018"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2017.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2017"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2016.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2015.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2014.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2013.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2012.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2011.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2011"
#     },
#     {},
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2010.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2009.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2008.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2008"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2007.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2006.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2005.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2004.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2004"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2003.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2002.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2001.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2000.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1999.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1998.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1997.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1996.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1995.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1994.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1993.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1992.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1991.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1990.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2021.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2020.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2019.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2018.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2018"
#     },
#     {},
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2017.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2017"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2016.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2015.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2014.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2013.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2012.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2011.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2011"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2010.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2009.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2008.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2008"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2007.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2006.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2005.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2004.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2004"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2003.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2002.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2001.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2000.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1999.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1998.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1997.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1996.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1995.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1993.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1992.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {},
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1991.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1990.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {}
# ]

# %%
from bs4 import BeautifulSoup
import requests
import json
 
base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
# data = []
i = 0
t_row_data = []
while True:
    payload = { 
        "value": 'Form W-2',
        "criteria": 'formNumber',
        'sortColumn': 'sortOrder',
        'indexOfFirstRow': i,
        'isDescending': 'false',
        'resultsPerPage': 25, 
    }
 
 
    r = requests.get(base_url, params=payload)
    c = r.content
    soup = BeautifulSoup(c, 'lxml')
    table = soup.find("table", class_= "picklist-dataTable")
    table_data = table.find_all('tr')
 
    headings = []
    for td in table_data[0].find_all("th"):
        headings.append(td.b.text.replace('\n', ' ').strip())
 
    for tr in table.find_all("tr"):
        t_row = {}
        for td, th in zip(tr.find_all("td"), headings): 
            # print(tr.td.a)
            t_row[th] = td.text.replace('\n', '').strip()
            t_row['link'] = tr.td.a['href']
        t_row_data.append(t_row)
    if t_row == {}:
       break
    i += 25
 
print(json.dumps(t_row_data, indent=4))
# Out:
# [
#     {},
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1990.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1989.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1989"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1988.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1988"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1987.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1987"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1986.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1986"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1985.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1985"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1984.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1984"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1983.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1983"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1982.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1982"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1981.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1981"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1980.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1980"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1979.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1979"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1978.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1978"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1977.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1977"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1976.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1976"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1975.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1975"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1974.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1974"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1973.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1973"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1972.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1972"
#     },
#     {
#         "Product Number": "Form W-2 P",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2p--1971.pdf",
#         "Title": "Statement For Recipients of Annuities, Pensions, Retired Pay, or IRA Payments",
#         "Revision Date": "1971"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2021.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2020.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2019.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2018.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2018"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2017.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2017"
#     },
#     {},
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2016.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2015.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2014.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2013.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2012.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2011.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2011"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2010.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2009.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2008.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2008"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2007.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2006.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2005.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2004.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2004"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2003.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2002.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2001.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--2000.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1999.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1998.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1997.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1996.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1995.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1994.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1993.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1992.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {},
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1991.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1990.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1989.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1989"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1988.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1988"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1987.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1987"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1986.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1986"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1985.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1985"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1984.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1984"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1983.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1983"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1982.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1982"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1981.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1981"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1980.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1980"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1979.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1979"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1978.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1978"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1977.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1977"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1976.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1976"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1975.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1975"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1974.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1974"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1973.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1973"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1972.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1972"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1971.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1971"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1970.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1970"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1969.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1969"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1966.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1966"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1965.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1965"
#     },
#     {},
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1964.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1964"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1963.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1963"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1962.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1962"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1961.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1961"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1960.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1960"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1959.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1959"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1958.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1958"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1957.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1957"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1956.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1956"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1955.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1955"
#     },
#     {
#         "Product Number": "Form W-2",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2--1954.pdf",
#         "Title": "Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1954"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2021.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2020.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2019.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2018.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2018"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2017.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2017"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2016.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2015.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2014.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2013.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2012.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2011.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2011"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2010.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2009.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2008.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2008"
#     },
#     {},
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2007.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2006.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2005.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2004.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2004"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2003.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2002.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2001.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--2000.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1999.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1998.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1997.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1996.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1995.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1994.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1993.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1992.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1991.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2AS",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2as--1990.pdf",
#         "Title": "American Samoa Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2014.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2009.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2006.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2002.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--2001.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1999.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1997.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {},
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1994.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1993.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1992.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1991.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1990.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1987.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1987"
#     },
#     {
#         "Product Number": "Form W-2C",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2c--1985.pdf",
#         "Title": "Corrected Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1985"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2021.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2020.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2019.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2018.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2018"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2017.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2017"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2016.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2015.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2014.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2013.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2012.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2011.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2011"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2010.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2009.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2008.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2008"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2007.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2006.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2005.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2004.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2004"
#     },
#     {},
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2003.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2002.pdf",
#         "Title": "Certain Gambling Winnings",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2001.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--2000.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1999.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1998.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1997.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1996.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1995.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1994.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1993.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1992.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1991.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2G",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2g--1990.pdf",
#         "Title": "Certain Gambling Winnings (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2021.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2020.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2019.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2018.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2018"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2017.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2017"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2016.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2015.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2014.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2013.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2012.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2011.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2011"
#     },
#     {},
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2010.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2009.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2008.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2008"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2007.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2006.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2005.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2004.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2004"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2003.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2002.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2001.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--2000.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1999.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1998.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1997.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1996.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1995.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1994.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1994"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1993.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1992.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1991.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2GU",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2gu--1990.pdf",
#         "Title": "Guam Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2021.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2021"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2020.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2020"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2019.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2019"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2018.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2018"
#     },
#     {},
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2017.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2017"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2016.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2016"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2015.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2015"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2014.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2014"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2013.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2013"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2012.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2012"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2011.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2011"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2010.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2010"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2009.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2009"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2008.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2008"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2007.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2007"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2006.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2006"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2005.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2005"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2004.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2004"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2003.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2003"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2002.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2002"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2001.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2001"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--2000.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "2000"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1999.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1999"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1998.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1998"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1997.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1997"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1996.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1996"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1995.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1995"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1993.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1993"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1992.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1992"
#     },
#     {},
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1991.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1991"
#     },
#     {
#         "Product Number": "Form W-2VI",
#         "link": "https://www.irs.gov/pub/irs-prior/fw2vi--1990.pdf",
#         "Title": "U.S. Virgin Islands Wage and Tax Statement (Info Copy Only)",
#         "Revision Date": "1990"
#     },
#     {}
# ]

# %%
from bs4 import BeautifulSoup
import requests
import json
 
 
def download_pdfs(form_name, year_range):
    base_url = 'https://apps.irs.gov/app/picklist/list/priorFormPublication.html'
    # data = []
    i = 0
    t_row_data = []
 
    while True:
        payload = { 
            "value": form_name,
            "criteria": 'formNumber',
            'sortColumn': 'sortOrder',
            'indexOfFirstRow': i,
            'isDescending': 'false',
            'resultsPerPage': 25, 
        }
 
 
        r = requests.get(base_url, params=payload)
        c = r.content
        soup = BeautifulSoup(c, 'lxml')
        table = soup.find("table", class_= "picklist-dataTable")
        table_data = table.find_all('tr')
 
        headings = []
        for td in table_data[0].find_all("th"):
            headings.append(td.b.text.replace('\n', ' ').strip())
 
 
        for tr in table.find_all("tr"):
            t_row = {}
            for td, th in zip(tr.find_all("td"), headings): 
                # print(tr.td.a)
                t_row[th] = td.text.replace('\n', '').strip()
                t_row['link'] = tr.td.a['href']
            t_row_data.append(t_row)
        if t_row == {}:
          break
        i += 25
 
    for row in t_row_data:
        if row != {} and row['Product Number'].lower() == form_name.lower():
          for row['Revision Date'] in year_range:
              response = requests.get(row['link'])
              with open(form_name+'-'+str(row['Revision Date'])+'.pdf', 'wb') as file:
                  file.write(response.content)
 
form_name = input("Enter the form you want to search for >>> ").strip()
start_year= int(input("Enter the year range >>> ").strip())
year_range = [start_year + i for i in range(3)]
 
download_pdfs(form_name, year_range)
# Out:
# Enter the form you want to search for >>> form w-2
# Enter the year range >>> 2000
